# %% [markdown]
# ## The purpose of this is to demo the pipeline and analytics functionality of LLMResponseMetrics. Please see the readme for more information.

# %%
from functions import *  # this is pulling functions from the function.py file in the code subfolder
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
import string

# %% [markdown]
# ## This is the code for running the core pipeline functionality

# %%
models_dict = {
    #'claude-2.1':  "ANTHROPIC", 
    'gpt-3.5-turbo-0301': "OPENAI"
               }  # these are the models that you want to actually test
csv_file_path = '../data/prompt_target_answer_pairs.csv' # set this filepath to the file that contains your question-answer pairs
similarity_model_name = 'sentence-transformers/paraphrase-mpnet-base-v2' # this is what you use for analyzing semantic similarity
temperature = "variable" # you can set this to a number between 0 and 1 if you don't want to vary temperature for the model responses
is_file_path = True # you can set this to false if you want to input data directly instead of via a file
llm_evaluation_model = ['gpt-4', "OPENAI"] # this is the model that will compare your target answer to the actual responses
instructions = "Please answer thoroughly: "
perturbation_model = ['gpt-4', "OPENAI"] # I recommend using a good model for perturbations otherwise it may generate the wrong number
stability_threshold= 3 # this is the number of period that the maximum score will have to be stable across all evaluation criteria before each prompt will stop running
max_runs= 6  # this is the maximum number of runs that each prompt will get run if the stability threshold is never met

pipeline = LLMAnalysisPipeline(
    input_data=csv_file_path, 
    models_dict=models_dict, 
    perturbation_model=perturbation_model, 
    llm_evaluation_model=llm_evaluation_model,
    temperature = temperature,
    max_runs= max_runs,
    is_file_path = is_file_path,
    similarity_model_name = similarity_model_name,
    instructions = instructions,
    stability_threshold = stability_threshold

)

# Run the pipeline
df_responses = pipeline.run_pipeline()
# Out:
# 2023-12-28 13:31:53,669 - INFO - Reading prompts from CSV file.
# 2023-12-28 13:32:03,963 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:32:03,970 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:32:17,597 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:32:17,601 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:32:28,707 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:32:28,711 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:32:51,772 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:32:51,776 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:09,319 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:09,324 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:25,050 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:25,056 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:30,197 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:30,202 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:33:34,518 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:34,522 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:34,524 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.9106574654579163, Keywords - 0.6428571428571429, LLM Rating - 0.9
# 2023-12-28 13:33:38,187 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:38,194 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:33:41,327 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:41,331 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:41,333 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.9268192052841187, Keywords - 0.6428571428571429, LLM Rating - 0.9
# 2023-12-28 13:33:45,007 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:45,012 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:33:48,342 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:48,348 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:48,349 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.8496574759483337, Keywords - 0.5, LLM Rating - 0.9
# 2023-12-28 13:33:48,350 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.9106574654579163, 0.9268192052841187, 0.9268192052841187]
# 2023-12-28 13:33:54,527 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:54,532 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:33:57,844 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:33:57,849 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:33:57,850 - INFO - Run 3, Model gpt-3.5-turbo-0301: Similarity - 0.8838499784469604, Keywords - 0.5714285714285714, LLM Rating - 0.9
# 2023-12-28 13:33:57,851 - INFO - Scores have stabilized across all metrics.
# 2023-12-28 13:33:57,852 - INFO - Stable scores achieved for prompt 'What is the powerhouse of the cell and how does it work?' after 4 runs. Moving to next prompt.
# 2023-12-28 13:34:00,422 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:00,428 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:03,197 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:03,202 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:03,203 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.8159322738647461, Keywords - 0.2, LLM Rating - 0.8
# 2023-12-28 13:34:05,421 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:05,426 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:07,765 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:07,770 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:07,771 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.9118854403495789, Keywords - 0.13333333333333333, LLM Rating - 0.9
# 2023-12-28 13:34:11,009 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:11,013 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:13,921 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:13,927 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:13,929 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.8378278613090515, Keywords - 0.2, LLM Rating - 0.9
# 2023-12-28 13:34:13,930 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.8159322738647461, 0.9118854403495789, 0.9118854403495789]
# 2023-12-28 13:34:15,989 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:15,994 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:18,571 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:18,576 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:18,577 - INFO - Run 3, Model gpt-3.5-turbo-0301: Similarity - 0.7809317708015442, Keywords - 0.3333333333333333, LLM Rating - 0.8
# 2023-12-28 13:34:18,578 - INFO - Scores for metric 'keyword_score' have not stabilized in the last 3 runs. Scores: [0.2, 0.2, 0.3333333333333333]
# 2023-12-28 13:34:21,703 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:21,708 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:24,505 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:24,509 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:24,510 - INFO - Run 4, Model gpt-3.5-turbo-0301: Similarity - 0.8234360218048096, Keywords - 0.26666666666666666, LLM Rating - 0.8
# 2023-12-28 13:34:24,511 - INFO - Scores for metric 'keyword_score' have not stabilized in the last 3 runs. Scores: [0.2, 0.3333333333333333, 0.3333333333333333]
# 2023-12-28 13:34:26,857 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:26,861 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:29,371 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:29,376 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:29,377 - INFO - Run 5, Model gpt-3.5-turbo-0301: Similarity - 0.8456656336784363, Keywords - 0.13333333333333333, LLM Rating - 0.8
# 2023-12-28 13:34:29,378 - INFO - Scores have stabilized across all metrics.
# 2023-12-28 13:34:29,379 - INFO - Stable scores achieved for prompt 'What is the basic unit of life and what does this mean?' after 6 runs. Moving to next prompt.
# 2023-12-28 13:34:31,974 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:31,980 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:34,639 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:34,644 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:34,646 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.7715303301811218, Keywords - 0.23076923076923078, LLM Rating - 0.9
# 2023-12-28 13:34:37,749 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:37,755 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:40,594 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:40,600 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:40,600 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.8041609525680542, Keywords - 0.5384615384615384, LLM Rating - 0.9
# 2023-12-28 13:34:44,443 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:44,464 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:47,313 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:47,320 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:47,322 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.6845816969871521, Keywords - 0.6153846153846154, LLM Rating - 0.9
# 2023-12-28 13:34:47,323 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.7715303301811218, 0.8041609525680542, 0.8041609525680542]
# 2023-12-28 13:34:52,888 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:52,893 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:34:55,962 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:34:55,967 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:34:55,968 - INFO - Run 3, Model gpt-3.5-turbo-0301: Similarity - 0.7918010354042053, Keywords - 0.6153846153846154, LLM Rating - 0.9
# 2023-12-28 13:34:55,969 - INFO - Scores for metric 'keyword_score' have not stabilized in the last 3 runs. Scores: [0.5384615384615384, 0.6153846153846154, 0.6153846153846154]
# 2023-12-28 13:35:00,846 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:00,851 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:04,957 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:04,979 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:04,981 - INFO - Run 4, Model gpt-3.5-turbo-0301: Similarity - 0.7549264430999756, Keywords - 0.8461538461538461, LLM Rating - 0.9
# 2023-12-28 13:35:04,986 - INFO - Scores for metric 'keyword_score' have not stabilized in the last 3 runs. Scores: [0.6153846153846154, 0.6153846153846154, 0.8461538461538461]
# 2023-12-28 13:35:08,476 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:08,482 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:11,242 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:11,247 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:11,248 - INFO - Run 5, Model gpt-3.5-turbo-0301: Similarity - 0.8162921071052551, Keywords - 0.38461538461538464, LLM Rating - 0.9
# 2023-12-28 13:35:11,249 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.8041609525680542, 0.8041609525680542, 0.8162921071052551]
# 2023-12-28 13:35:14,927 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:14,933 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:17,637 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:17,642 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:17,643 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.4732738137245178, Keywords - 0.0, LLM Rating - 0.1
# 2023-12-28 13:35:20,341 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:20,347 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:22,982 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:22,988 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:22,990 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.43650496006011963, Keywords - 0.0, LLM Rating - 0.1
# 2023-12-28 13:35:26,214 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:26,219 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:28,754 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:28,759 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:28,761 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.4463306665420532, Keywords - 0.0, LLM Rating - 0.1
# 2023-12-28 13:35:28,762 - INFO - Scores have stabilized across all metrics.
# 2023-12-28 13:35:28,763 - INFO - Stable scores achieved for prompt 'Which organelle contains the cell's futurogenic material and how does it work?' after 3 runs. Moving to next prompt.
# 2023-12-28 13:35:32,073 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:32,079 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:36,769 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:36,775 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:36,777 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.6558848023414612, Keywords - 0.1111111111111111, LLM Rating - 0.1
# 2023-12-28 13:35:37,548 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:37,555 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:40,151 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:40,159 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:40,160 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.5129074454307556, Keywords - 0.0, LLM Rating - 0.0
# 2023-12-28 13:35:44,211 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:44,224 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:47,521 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:47,526 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:47,527 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.507900059223175, Keywords - 0.0, LLM Rating - 0.0
# 2023-12-28 13:35:47,529 - INFO - Scores have stabilized across all metrics.
# 2023-12-28 13:35:47,530 - INFO - Stable scores achieved for prompt 'What particle stabilizes the membrane of hover frogs and how?' after 3 runs. Moving to next prompt.
# 2023-12-28 13:35:52,145 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:52,152 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:35:55,283 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:55,289 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:35:55,291 - INFO - Run 0, Model gpt-3.5-turbo-0301: Similarity - 0.6649944186210632, Keywords - 0.36363636363636365, LLM Rating - 0.2
# 2023-12-28 13:35:59,124 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:35:59,128 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:36:02,716 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:02,722 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:36:02,723 - INFO - Run 1, Model gpt-3.5-turbo-0301: Similarity - 0.8280273079872131, Keywords - 0.2727272727272727, LLM Rating - 0.7
# 2023-12-28 13:36:07,880 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:07,884 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:36:11,344 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:11,352 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:36:11,353 - INFO - Run 2, Model gpt-3.5-turbo-0301: Similarity - 0.844747006893158, Keywords - 0.36363636363636365, LLM Rating - 0.8
# 2023-12-28 13:36:11,355 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.6649944186210632, 0.8280273079872131, 0.844747006893158]
# 2023-12-28 13:36:15,641 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:15,646 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:36:18,957 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:18,963 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:36:18,964 - INFO - Run 3, Model gpt-3.5-turbo-0301: Similarity - 0.8386579751968384, Keywords - 0.2727272727272727, LLM Rating - 0.6
# 2023-12-28 13:36:18,965 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.8280273079872131, 0.844747006893158, 0.844747006893158]
# 2023-12-28 13:36:23,025 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:23,031 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:36:26,531 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:26,536 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:36:26,538 - INFO - Run 4, Model gpt-3.5-turbo-0301: Similarity - 0.8463970422744751, Keywords - 0.2727272727272727, LLM Rating - 0.7
# 2023-12-28 13:36:26,539 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.844747006893158, 0.844747006893158, 0.8463970422744751]
# 2023-12-28 13:36:30,106 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:30,113 - INFO - API call successful. Model: gpt-3.5-turbo-0301, Provider: OPENAI
# 2023-12-28 13:36:33,500 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2023-12-28 13:36:33,504 - INFO - API call successful. Model: gpt-4, Provider: OPENAI
# 2023-12-28 13:36:33,505 - INFO - Run 5, Model gpt-3.5-turbo-0301: Similarity - 0.8346473574638367, Keywords - 0.2727272727272727, LLM Rating - 0.6
# 2023-12-28 13:36:33,506 - INFO - Scores for metric 'similarity_score' have not stabilized in the last 3 runs. Scores: [0.844747006893158, 0.8463970422744751, 0.8463970422744751]

# %% [markdown]
# ## This is what the response table looks like

# %%
df_responses
# Out:
#                  model                                    original_prompt  \
# 0   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 1   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 2   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 3   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 4   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 5   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 6   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 7   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 8   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 9   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 10  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 11  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 12  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 13  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 14  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 15  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 16  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
# 17  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
# 18  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
# 19  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 20  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 21  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 22  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 23  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 24  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 25  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 26  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 27  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
#
#                                              response  temperature  \
# 0   The cell's powerhouse is the mitochondria, whi...     0.391784
# 1   The powerhouse of the cell is the mitochondria...     0.496671
# 2   The energy production center of the cell is kn...     0.977080
# 3   The cell's energy factory is the mitochondria,...     0.361931
# 4   The key unit of life is the cell. A cell is th...     0.336419
# 5   The basic unit of life is the cell. This means...     0.525557
# 6   The fundamental unit of life is the cell. A ce...     0.261278
# 7   The elemental unit of life is the cell. It den...     0.592574
# 8   The essential unit of life is the cell. A cell...     0.185147
# 9   The simplest unit of life is the cell. A cell ...     0.945666
# 10  Genes are segments of DNA that contain the ins...     0.079821
# 11  Genes are the basic unit of heredity and are c...     0.747921
# 12  The elements of genes are the basic units of g...     0.960792
# 13  Genes are the basic unit of heredity that carr...     0.305154
# 14  The constituents of genes are DNA (deoxyribonu...     0.851195
# 15  Genes are the basic units of heredity and cons...     0.907674
# 16  The organelle that contains the cell's genetic...     0.555533
# 17  The organelle in the cell that is the reposito...     0.417024
# 18  The organelle that is the storage site for the...     0.186472
# 19  As an AI language model, I cannot find any sci...     0.831165
# 20  As an AI language model, I cannot provide an a...     0.724859
# 21  As an AI language model, I do not have any inf...     0.671809
# 22  As an AI language model, I don't have informat...     0.231713
# 23  Astroflora, also known as space plants, are pl...     0.613185
# 24  Astroflora, also known as space plants, are pl...     0.914575
# 25  Astroflora are a type of plant that are able t...     0.599534
# 26  Astroflora, also known as space plants, are pl...     0.897160
# 27  Astroflora, also known as space plants, are pl...     0.037056
#
#                                         actual_prompt  run_number  \
# 0   - Can you explain the function of the cell's p...           0
# 1   What is the powerhouse of the cell and how doe...           1
# 2   - What is the energy production center of the ...           2
# 3   - Can you describe the cell's energy factory a...           3
# 4   - What is the key unit of life and what is its...           0
# 5   What is the basic unit of life and what does t...           1
# 6   - What is the fundamental unit of life and can...           2
# 7   - What is the elemental unit of life and what ...           3
# 8   - What is the essential unit of life and what ...           4
# 9   - What is the simplest unit of life and what i...           5
# 10  - What constitutes genes and how do they perfo...           0
# 11  - What is the composition and functionality of...           1
# 12  - What are the elements of genes and how do th...           2
# 13  - What are the components of genes and their f...           3
# 14  - What are the constituents of genes and how d...           4
# 15     What do genes consist of and how do they work?           5
# 16  Which organelle contains the cell's futurogeni...           0
# 17  - Which organelle in the cell is the repositor...           1
# 18  - Which organelle is the storage site for the ...           2
# 19  - What is the particle that maintains the stab...           0
# 20  - Which particle is responsible for the stabil...           1
# 21  - What is the particle that contributes to the...           2
# 22  - What is the mechanism of photosynthesis in a...           0
# 23  How do astroflora perform photosynthesis in lo...           1
# 24  - How is it possible for astroflora to perform...           2
# 25  - How do astroflora manage to perform photosyn...           3
# 26  - How do astroflora execute the process of pho...           4
# 27  - In what way do astroflora carry out photosyn...           5
#
#     similarity_score  keyword_score  llm_rating  \
# 0           0.910657       0.642857         0.9
# 1           0.926819       0.642857         0.9
# 2           0.849657       0.500000         0.9
# 3           0.883850       0.571429         0.9
# 4           0.815932       0.200000         0.8
# 5           0.911885       0.133333         0.9
# 6           0.837828       0.200000         0.9
# 7           0.780932       0.333333         0.8
# 8           0.823436       0.266667         0.8
# 9           0.845666       0.133333         0.8
# 10          0.771530       0.230769         0.9
# 11          0.804161       0.538462         0.9
# 12          0.684582       0.615385         0.9
# 13          0.791801       0.615385         0.9
# 14          0.754926       0.846154         0.9
# 15          0.816292       0.384615         0.9
# 16          0.473274       0.000000         0.1
# 17          0.436505       0.000000         0.1
# 18          0.446331       0.000000         0.1
# 19          0.655885       0.111111         0.1
# 20          0.512907       0.000000         0.0
# 21          0.507900       0.000000         0.0
# 22          0.664994       0.363636         0.2
# 23          0.828027       0.272727         0.7
# 24          0.844747       0.363636         0.8
# 25          0.838658       0.272727         0.6
# 26          0.846397       0.272727         0.7
# 27          0.834647       0.272727         0.6
#
#                                              keywords
# 0   [mitochondrion, mitochondria, atp, adenosine t...
# 1   [mitochondrion, mitochondria, atp, adenosine t...
# 2   [mitochondrion, mitochondria, atp, adenosine t...
# 3   [mitochondrion, mitochondria, atp, adenosine t...
# 4   [cell, biology, prokaryotic cells, eukaryotic ...
# 5   [cell, biology, prokaryotic cells, eukaryotic ...
# 6   [cell, biology, prokaryotic cells, eukaryotic ...
# 7   [cell, biology, prokaryotic cells, eukaryotic ...
# 8   [cell, biology, prokaryotic cells, eukaryotic ...
# 9   [cell, biology, prokaryotic cells, eukaryotic ...
# 10  [genes, dna, deoxyribonucleic acid, nucleotide...
# 11  [genes, dna, deoxyribonucleic acid, nucleotide...
# 12  [genes, dna, deoxyribonucleic acid, nucleotide...
# 13  [genes, dna, deoxyribonucleic acid, nucleotide...
# 14  [genes, dna, deoxyribonucleic acid, nucleotide...
# 15  [genes, dna, deoxyribonucleic acid, nucleotide...
# 16  [chronocytum, futurogenic material, temporal a...
# 17  [chronocytum, futurogenic material, temporal a...
# 18  [chronocytum, futurogenic material, temporal a...
# 19  [levitonium, hover frogs, membrane stabilizati...
# 20  [levitonium, hover frogs, membrane stabilizati...
# 21  [levitonium, hover frogs, membrane stabilizati...
# 22  [astroflora, photosynthesis, low light conditi...
# 23  [astroflora, photosynthesis, low light conditi...
# 24  [astroflora, photosynthesis, low light conditi...
# 25  [astroflora, photosynthesis, low light conditi...
# 26  [astroflora, photosynthesis, low light conditi...
# 27  [astroflora, photosynthesis, low light conditi...

# %% [markdown]
# ## This shows how many times each prompt ran and which run produced the best score

# %%
def analyze_best_scores(df_responses):
    methods = ['similarity_score', 'keyword_score', 'llm_rating']
    
    # Group by model, original prompt, and run number, then compute the max score for each method
    max_scores = df_responses.groupby(['model', 'original_prompt', 'run_number'])[methods].max()

    # Find the run number with the highest score for each method per prompt and model
    best_runs = max_scores.groupby(level=[0, 1]).idxmax()

    # Extract the run number and create a DataFrame
    best_run_info = best_runs.map(lambda x: x[2] if pd.notna(x) else None)
    best_run_info.columns = [f'best_run_{method}' for method in methods]

    # Add total run count for each prompt and model
    total_runs = df_responses.groupby(['model', 'original_prompt'])['run_number'].nunique()
    best_run_info['total_runs'] = total_runs

    best_run_info.reset_index(inplace=True)
    best_run_info.rename(columns={'original_prompt': 'prompt'}, inplace=True)

    return best_run_info

df_best_scores = analyze_best_scores(df_responses)
df_best_scores
# Out:
#                 model                                             prompt  \
# 0  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 1  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 2  gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 3  gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 4  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 5  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
#
#    best_run_similarity_score  best_run_keyword_score  best_run_llm_rating  \
# 0                          4                       0                    2
# 1                          5                       4                    0
# 2                          1                       3                    1
# 3                          1                       0                    0
# 4                          0                       0                    0
# 5                          0                       0                    0
#
#    total_runs
# 0           6
# 1           6
# 2           6
# 3           4
# 4           3
# 5           3

# %% [markdown]
# ## This shows the best response for each prompt by similarity score

# %%
aggregate_best_scores(df_responses, "similarity_score")
# Out:
#                  model                                    original_prompt  \
# 26  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 15  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 5   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 1   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 19  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 16  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
#
#                                         actual_prompt  \
# 26  - How do astroflora execute the process of pho...
# 15     What do genes consist of and how do they work?
# 5   What is the basic unit of life and what does t...
# 1   What is the powerhouse of the cell and how doe...
# 19  - What is the particle that maintains the stab...
# 16  Which organelle contains the cell's futurogeni...
#
#                                              response  similarity_score
# 26  Astroflora, also known as space plants, are pl...          0.846397
# 15  Genes are the basic units of heredity and cons...          0.816292
# 5   The basic unit of life is the cell. This means...          0.911885
# 1   The powerhouse of the cell is the mitochondria...          0.926819
# 19  As an AI language model, I cannot find any sci...          0.655885
# 16  The organelle that contains the cell's genetic...          0.473274

# %% [markdown]
# ## This shows the best response for each prompt by keyword score

# %%
aggregate_best_scores(df_responses, 'keyword_score')
# Out:
#                  model                                    original_prompt  \
# 22  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 14  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 7   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 0   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 19  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 16  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
#
#                                         actual_prompt  \
# 22  - What is the mechanism of photosynthesis in a...
# 14  - What are the constituents of genes and how d...
# 7   - What is the elemental unit of life and what ...
# 0   - Can you explain the function of the cell's p...
# 19  - What is the particle that maintains the stab...
# 16  Which organelle contains the cell's futurogeni...
#
#                                              response  keyword_score
# 22  As an AI language model, I don't have informat...       0.363636
# 14  The constituents of genes are DNA (deoxyribonu...       0.846154
# 7   The elemental unit of life is the cell. It den...       0.333333
# 0   The cell's powerhouse is the mitochondria, whi...       0.642857
# 19  As an AI language model, I cannot find any sci...       0.111111
# 16  The organelle that contains the cell's genetic...       0.000000

# %% [markdown]
# ## This shows the best response for each prompt by LLM rating

# %%
aggregate_best_scores(df_responses, 'llm_rating')
# Out:
#                  model                                    original_prompt  \
# 24  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 10  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 5   gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 0   gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 19  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 16  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
#
#                                         actual_prompt  \
# 24  - How is it possible for astroflora to perform...
# 10  - What constitutes genes and how do they perfo...
# 5   What is the basic unit of life and what does t...
# 0   - Can you explain the function of the cell's p...
# 19  - What is the particle that maintains the stab...
# 16  Which organelle contains the cell's futurogeni...
#
#                                              response  llm_rating
# 24  Astroflora, also known as space plants, are pl...         0.8
# 10  Genes are segments of DNA that contain the ins...         0.9
# 5   The basic unit of life is the cell. This means...         0.9
# 0   The cell's powerhouse is the mitochondria, whi...         0.9
# 19  As an AI language model, I cannot find any sci...         0.1
# 16  The organelle that contains the cell's genetic...         0.1

# %% [markdown]
# ## This shows the spread in terms of responses by prompt and method

# %%
def calculate_spread(df_responses):
    methods = ['similarity_score', 'keyword_score', 'llm_rating']
    
    # Group by model and original prompt
    grouped = df_responses.groupby(['model', 'original_prompt'])

    # Aggregate the data to find the max, min, and std for each method
    agg_functions = {method: ['max', 'min'] for method in methods}
    spread_df = grouped.agg(agg_functions).reset_index()

    # Flatten MultiIndex columns
    spread_df.columns = ['_'.join(col).strip() if col[1] else col[0] for col in spread_df.columns.values]

    return spread_df

calculate_spread(df_responses)
# Out:
#                 model                                    original_prompt  \
# 0  gpt-3.5-turbo-0301  How do astroflora perform photosynthesis in lo...
# 1  gpt-3.5-turbo-0301     What do genes consist of and how do they work?
# 2  gpt-3.5-turbo-0301  What is the basic unit of life and what does t...
# 3  gpt-3.5-turbo-0301  What is the powerhouse of the cell and how doe...
# 4  gpt-3.5-turbo-0301  What particle stabilizes the membrane of hover...
# 5  gpt-3.5-turbo-0301  Which organelle contains the cell's futurogeni...
#
#    similarity_score_max  similarity_score_min  keyword_score_max  \
# 0              0.846397              0.664994           0.363636
# 1              0.816292              0.684582           0.846154
# 2              0.911885              0.780932           0.333333
# 3              0.926819              0.849657           0.642857
# 4              0.655885              0.507900           0.111111
# 5              0.473274              0.436505           0.000000
#
#    keyword_score_min  llm_rating_max  llm_rating_min
# 0           0.272727             0.8             0.2
# 1           0.230769             0.9             0.9
# 2           0.133333             0.9             0.8
# 3           0.500000             0.9             0.9
# 4           0.000000             0.1             0.0
# 5           0.000000             0.1             0.1
